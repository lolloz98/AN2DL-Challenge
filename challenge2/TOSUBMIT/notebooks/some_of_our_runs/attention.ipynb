# %%
# Set to false if working on local env
onColab = True

model_path = './attentionmodel'

# Decide batch size and validation split
batch_size = 16
validation_split = 0.2
test_split = 0.01
epochs = 200

dataset_path = './Training_smooth4.csv'

window = 600
stride = 10
# 864 / 8
telescope = 108

# %%
if onColab:
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/MyDrive/University/ANN/CHALLENGE2
  # !ls
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/University/ANN/CHALLENGE2
#  3_7424			       inno_training_smooth_4
# '3_7424 - drop'		       inno_training_smooth_4_tel144
#  aaa			       inno_training_smooth_5
# 'att e1d1'		       model.png
#  attmodel		       multimodel_2
#  attmodel0		       multi_model_2.ipynb
# 'attmodel bigger'	       sets
#  baseline		       smooth11
#  baseline_ckpt		       smooth15
# 'baseline copy.ipynb'	       smooth21
#  baseline.ipynb		       smooth7
# 'div smooth senza lrr_ckpt'    test2
# 'div smooth senza lrr.ipynb'   test2_ckpt
#  e1d1_tel288_div	       test2.ipynb
#  e1d1_tel288_div.ipynb	       test4.ipynb
#  e2d2_div		       test5.ipynb
#  e2d2_div_5stride	       Training.csv
#  e2d2_div.ipynb		       Training_smooth4.csv
#  e2d2_tel288		       withoutlrr
#  e2d2_tel288.ipynb	       withoutlrr_ckpt

# %%
#@title Import libraries
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
#@title init seed everywhere
seed =20

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset  = pd.read_csv(dataset_path)
print(dataset.shape)
dataset.head()
# Out:
# (68480, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0    5.484983      5.713692  ...          31.723626   4.450450
# 1    5.485001      5.713655  ...          31.723948   4.450430
# 2    5.485237      5.713199  ...          31.727915   4.450184
# 3    5.486135      5.711522  ...          31.742346   4.449323
# 4    5.488279      5.707682  ...          31.775062   4.447453
#
# [5 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68480 entries, 0 to 68479
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68480 non-null  float64
#  1   Wonder level        68480 non-null  float64
#  2   Crunchiness         68480 non-null  float64
#  3   Loudness on impact  68480 non-null  float64
#  4   Meme creativity     68480 non-null  float64
#  5   Soap slipperiness   68480 non-null  float64
#  6   Hype root           68480 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %%
test_size = round(dataset.shape[0] * test_split)
X_train_raw = dataset.iloc[:-test_size]
# y_train_raw = y.iloc[:-test_size]
X_test_raw = dataset.iloc[-test_size:]
# y_test_raw = y.iloc[-test_size:]
print(X_train_raw.shape, X_test_raw.shape)

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_noNorm = X_train_raw
X_test_noNorm = X_test_raw

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)
# Out:
# (67795, 7) (685, 7)

# %%
plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Sponginess, label='Train (sponginess)')
plt.plot(X_test_raw.Sponginess, label='Test (sponginess)')
plt.title('Train-Test Split')
plt.legend()
plt.show()

# %%
future = dataset[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 600, 7)

# %%
def build_sequences(df, target_labels=['Sponginess'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
target_labels = dataset.columns

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6710, 600, 7), (6710, 108, 7), (50, 600, 7), (50, 108, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
X_train.shape
# Out:
# (6710, 600, 7)

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
input_shape, output_shape
# Out:
# ((600, 7), (108, 7))

# %%
def build_model(input_shape, output_shape):
    
    n_hidden = 300
    input_train = tfkl.Input(shape=input_shape)
    output_train = tfkl.Input(shape=output_shape)

    encoder_stack_h, encoder_last_h, encoder_last_c = tfkl.LSTM(
        n_hidden,
        return_state=True, return_sequences=True)(input_train)
    
    decoder_input = tfkl.RepeatVector(output_train.shape[1])(encoder_last_h)
    print(decoder_input)

    decoder_stack_h = tfkl.LSTM(n_hidden,
        return_state=False, return_sequences=True)(
        decoder_input, initial_state=[encoder_last_h, encoder_last_c])
    print(decoder_stack_h)
    attention = tfkl.dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
    attention = tfkl.Activation('softmax')(attention)
    print(attention)

    context = tfkl.dot([attention, encoder_stack_h], axes=[2,1])
    print(context)
    
    decoder_combined_context = tfkl.concatenate([context, decoder_stack_h])
    print(decoder_combined_context)

    out = tfkl.TimeDistributed(tfkl.Dense(output_shape[1]))(decoder_combined_context)

    model = tfk.Model(inputs=input_train, outputs=out)
    
    opt = tfk.optimizers.Adam(clipnorm=1, learning_rate=0.01)

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=opt, metrics=['mae'])
    
    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 108, 300), dtype=tf.float32, name=None), name='repeat_vector/Tile:0', description="created by layer 'repeat_vector'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 108, 300), dtype=tf.float32, name=None), name='lstm_1/PartitionedCall:1', description="created by layer 'lstm_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 108, 600), dtype=tf.float32, name=None), name='activation/Softmax:0', description="created by layer 'activation'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 108, 300), dtype=tf.float32, name=None), name='dot_1/MatMul:0', description="created by layer 'dot_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 108, 600), dtype=tf.float32, name=None), name='concatenate/concat:0', description="created by layer 'concatenate'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 600, 7)]     0           []
#
#  lstm (LSTM)                    [(None, 600, 300),   369600      ['input_1[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  repeat_vector (RepeatVector)   (None, 108, 300)     0           ['lstm[0][1]']
#
#  lstm_1 (LSTM)                  (None, 108, 300)     721200      ['repeat_vector[0][0]',
#                                                                   'lstm[0][1]',
#                                                                   'lstm[0][2]']
#
#  dot (Dot)                      (None, 108, 600)     0           ['lstm_1[0][0]',
#                                                                   'lstm[0][0]']
#
#  activation (Activation)        (None, 108, 600)     0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 108, 300)     0           ['activation[0][0]',
#                                                                   'lstm[0][0]']
#
#  concatenate (Concatenate)      (None, 108, 600)     0           ['dot_1[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  time_distributed (TimeDistribu  (None, 108, 7)      4207        ['concatenate[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 1,095,007
# Trainable params: 1,095,007
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = validation_split,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=30, restore_best_weights=True),
        # tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5),
        # tfk.callbacks.ModelCheckpoint(model_path + '_ckpt', save_best_only=True)
    ]
).history
# Out:
# Epoch 1/200
# 336/336 [==============================] - 21s 44ms/step - loss: 0.0735 - mae: 0.1342 - val_loss: 0.0286 - val_mae: 0.1324
# Epoch 2/200
# 336/336 [==============================] - 14s 42ms/step - loss: 0.0221 - mae: 0.1125 - val_loss: 0.0258 - val_mae: 0.1226
# Epoch 3/200
# 336/336 [==============================] - 14s 42ms/step - loss: 0.0222 - mae: 0.1083 - val_loss: 0.0200 - val_mae: 0.1092
# Epoch 4/200
# 336/336 [==============================] - 14s 43ms/step - loss: 0.0901 - mae: 0.1120 - val_loss: 0.0206 - val_mae: 0.1052
# Epoch 5/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0878 - mae: 0.1080 - val_loss: 0.0218 - val_mae: 0.1033
# Epoch 6/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0950 - mae: 0.1006 - val_loss: 0.0220 - val_mae: 0.1174
# Epoch 7/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0576 - mae: 0.0955 - val_loss: 0.0186 - val_mae: 0.1047
# Epoch 8/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0137 - mae: 0.0875 - val_loss: 0.0169 - val_mae: 0.0944
# Epoch 9/200
# 336/336 [==============================] - 14s 43ms/step - loss: 0.0126 - mae: 0.0837 - val_loss: 0.0181 - val_mae: 0.0943
# Epoch 10/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0111 - mae: 0.0781 - val_loss: 0.0150 - val_mae: 0.0894
# Epoch 11/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0105 - mae: 0.0752 - val_loss: 0.0143 - val_mae: 0.0836
# Epoch 12/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0102 - mae: 0.0742 - val_loss: 0.0155 - val_mae: 0.0934
# Epoch 13/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0091 - mae: 0.0700 - val_loss: 0.0122 - val_mae: 0.0804
# Epoch 14/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0080 - mae: 0.0660 - val_loss: 0.0119 - val_mae: 0.0749
# Epoch 15/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0076 - mae: 0.0645 - val_loss: 0.0103 - val_mae: 0.0710
# Epoch 16/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0066 - mae: 0.0602 - val_loss: 0.0097 - val_mae: 0.0736
# Epoch 17/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0066 - mae: 0.0602 - val_loss: 0.0089 - val_mae: 0.0690
# Epoch 18/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0065 - mae: 0.0595 - val_loss: 0.0101 - val_mae: 0.0759
# Epoch 19/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0062 - mae: 0.0578 - val_loss: 0.0082 - val_mae: 0.0669
# Epoch 20/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0059 - mae: 0.0564 - val_loss: 0.0096 - val_mae: 0.0719
# Epoch 21/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0059 - mae: 0.0565 - val_loss: 0.0089 - val_mae: 0.0697
# Epoch 22/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0057 - mae: 0.0550 - val_loss: 0.0088 - val_mae: 0.0654
# Epoch 23/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0054 - mae: 0.0537 - val_loss: 0.0088 - val_mae: 0.0664
# Epoch 24/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0056 - mae: 0.0549 - val_loss: 0.0091 - val_mae: 0.0708
# Epoch 25/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0054 - mae: 0.0537 - val_loss: 0.0097 - val_mae: 0.0704
# Epoch 26/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0052 - mae: 0.0527 - val_loss: 0.0090 - val_mae: 0.0660
# Epoch 27/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0051 - mae: 0.0515 - val_loss: 0.0090 - val_mae: 0.0691
# Epoch 28/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0057 - mae: 0.0550 - val_loss: 0.0091 - val_mae: 0.0702
# Epoch 29/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0351 - mae: 0.0750 - val_loss: 0.0136 - val_mae: 0.0850
# Epoch 30/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0074 - mae: 0.0633 - val_loss: 0.0097 - val_mae: 0.0715
# Epoch 31/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0062 - mae: 0.0580 - val_loss: 0.0087 - val_mae: 0.0671
# Epoch 32/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0056 - mae: 0.0545 - val_loss: 0.0090 - val_mae: 0.0708
# Epoch 33/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0055 - mae: 0.0544 - val_loss: 0.0096 - val_mae: 0.0720
# Epoch 34/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0052 - mae: 0.0525 - val_loss: 0.0081 - val_mae: 0.0649
# Epoch 35/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0053 - mae: 0.0527 - val_loss: 0.0087 - val_mae: 0.0693
# Epoch 36/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0051 - mae: 0.0517 - val_loss: 0.0074 - val_mae: 0.0623
# Epoch 37/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0048 - mae: 0.0503 - val_loss: 0.0082 - val_mae: 0.0653
# Epoch 38/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0048 - mae: 0.0497 - val_loss: 0.0078 - val_mae: 0.0637
# Epoch 39/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0944 - mae: 0.1466 - val_loss: 0.0181 - val_mae: 0.1001
# Epoch 40/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0292 - mae: 0.1175 - val_loss: 0.0222 - val_mae: 0.1087
# Epoch 41/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0141 - mae: 0.0880 - val_loss: 0.0169 - val_mae: 0.0945
# Epoch 42/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0123 - mae: 0.0811 - val_loss: 0.0151 - val_mae: 0.0889
# Epoch 43/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0121 - mae: 0.0808 - val_loss: 0.0180 - val_mae: 0.1027
# Epoch 44/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0116 - mae: 0.0792 - val_loss: 0.0149 - val_mae: 0.0885
# Epoch 45/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0111 - mae: 0.0772 - val_loss: 0.0151 - val_mae: 0.0902
# Epoch 46/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0108 - mae: 0.0760 - val_loss: 0.0148 - val_mae: 0.0858
# Epoch 47/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0105 - mae: 0.0748 - val_loss: 0.0163 - val_mae: 0.0866
# Epoch 48/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0105 - mae: 0.0750 - val_loss: 0.0167 - val_mae: 0.0962
# Epoch 49/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0104 - mae: 0.0745 - val_loss: 0.0165 - val_mae: 0.0835
# Epoch 50/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0102 - mae: 0.0739 - val_loss: 0.0146 - val_mae: 0.0881
# Epoch 51/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0104 - mae: 0.0748 - val_loss: 0.0156 - val_mae: 0.0931
# Epoch 52/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0105 - mae: 0.0756 - val_loss: 0.0183 - val_mae: 0.1043
# Epoch 53/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0102 - mae: 0.0734 - val_loss: 0.0151 - val_mae: 0.0916
# Epoch 54/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0102 - mae: 0.0739 - val_loss: 0.0151 - val_mae: 0.0869
# Epoch 55/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0099 - mae: 0.0725 - val_loss: 0.0145 - val_mae: 0.0860
# Epoch 56/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0101 - mae: 0.0732 - val_loss: 0.0162 - val_mae: 0.0940
# Epoch 57/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0097 - mae: 0.0717 - val_loss: 0.0148 - val_mae: 0.0859
# Epoch 58/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0099 - mae: 0.0724 - val_loss: 0.0159 - val_mae: 0.0931
# Epoch 59/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0101 - mae: 0.0735 - val_loss: 0.0155 - val_mae: 0.0929
# Epoch 60/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0099 - mae: 0.0729 - val_loss: 0.0143 - val_mae: 0.0844
# Epoch 61/200
# 336/336 [==============================] - 15s 43ms/step - loss: 0.0096 - mae: 0.0712 - val_loss: 0.0144 - val_mae: 0.0876
# Epoch 62/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0096 - mae: 0.0712 - val_loss: 0.0138 - val_mae: 0.0809
# Epoch 63/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0094 - mae: 0.0706 - val_loss: 0.0154 - val_mae: 0.0941
# Epoch 64/200
# 336/336 [==============================] - 16s 48ms/step - loss: 0.0094 - mae: 0.0704 - val_loss: 0.0145 - val_mae: 0.0828
# Epoch 65/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0094 - mae: 0.0703 - val_loss: 0.0147 - val_mae: 0.0874
# Epoch 66/200
# 336/336 [==============================] - 15s 44ms/step - loss: 0.0094 - mae: 0.0709 - val_loss: 0.0141 - val_mae: 0.0795

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f3cdf158910> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f3cd0216b90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model(model_path)

# %%
# Predict the test set 
predictions = model.predict(X_test)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (50, 108, 7)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.023479277>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.12658009>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
future_predictions = model.predict(future)

# %%
figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
for i, col in enumerate(target_labels):
    axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
    axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), future_predictions[0,:,i], color='orange')
    axs[i].fill_between(
        np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), 
        future_predictions[0,:,i]+maes[:,i], 
        future_predictions[0,:,i]-maes[:,i], 
        color='orange', alpha=.3)
    axs[i].set_title(col)
    # axs[i].set_ylim(0,1)
plt.show()

# %%
reg_telescope = 216
X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
X_test_reg.shape, y_test_reg.shape
# Out:
# ((39, 600, 7), (39, 216, 7))

# %%
# Autoregressive Forecasting
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
reg_predictions.shape
# Out:
# (39, 216, 7)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.04360623>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.16882831>)

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, target_labels, reg_telescope, 38)
