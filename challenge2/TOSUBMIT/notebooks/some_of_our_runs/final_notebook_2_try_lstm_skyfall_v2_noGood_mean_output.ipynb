# %%
onColab = True
model_path = './inno_training_no_smooth_final_864_2'

# Decide batch size and validation split
batch_size = 128
validation_split = 0.25
epochs = 100

dataset_path = './Training.csv'

window = 864
stride = 8
# 864 / 8
telescope = 864

# %% [markdown]
# ## Init
# Initialize codalab, libraries and seed

# %%
#@title connect to codalab
if onColab:
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/MyDrive/University/ANN/CHALLENGE2
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1wUooQX2JQMXbJQAiDLoK7kUddfk8JdBM/CHALLENGE2

# %%
#@title Import libraries
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import sklearn
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
#@title init seed everywhere
seed = 32

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ## Dataset import and manipulation

# %%
dataset  = pd.read_csv(dataset_path)
print(dataset.shape)
dataset.describe()
# Out:
# (68528, 7)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       6.094102      4.695539  ...          23.237929      8.231283
# std        1.941639      3.374224  ...          14.298260     11.285101
# min       -0.972080     -8.450380  ...          -6.006860    -42.769221
# 25%        4.791440      2.223420  ...          12.560240      6.604160
# 50%        5.702780      4.668600  ...          20.151420     10.968300
# 75%        7.067300      7.115440  ...          31.245199     15.334100
# max       15.106680     18.122899  ...          77.371620     31.024420
#
# [8 rows x 7 columns]

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
# inspect_dataframe(dataset, dataset.columns)

# %%
def normalize(dataset, t=None):
  if t is None or t == 'minmax':
    x_min = dataset.min(axis=0)
    print(x_min.shape)
    x_max = dataset.max()
    nd = (dataset - x_min) / (x_max - x_min)
    return nd
  elif t == 'mean_std':
    x_mean = dataset.mean()
    x_std = dataset.std()
    nd = (dataset - x_mean) / x_std
    return nd

# %%
# dataset = dataset[['Sponginess', 'Crunchiness', 'Hype root']]
# dataset.describe()

# %%
normalized_ds = normalize(dataset)
normalized_ds.describe()
# Out:
# (7,)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       0.439473      0.494704  ...           0.350747      0.691123
# std        0.120758      0.126978  ...           0.171486      0.152928
# min        0.000000      0.000000  ...           0.000000      0.000000
# 25%        0.358455      0.401674  ...           0.222685      0.669074
# 50%        0.415135      0.493691  ...           0.313729      0.728213
# 75%        0.500000      0.585770  ...           0.446783      0.787376
# max        1.000000      1.000000  ...           1.000000      1.000000
#
# [8 rows x 7 columns]

# %%
import math
def chunk(dataset, window, telescope, stride):
  """
  divide the dataset in chunks. 
  It keeps the right-most elements and discard the left ones, if size and stride are not compatible with dimensions. 
  """
  size = window + telescope
  X = []
  Y = []
  for i in range(len(dataset) - size, -1, -stride):
    
    # count = 0
    # prev = 0
    # for ds in dataset.filter(range(i, i + size), axis=0)['Crunchiness']:
    #   if math.isclose(prev, ds, rel_tol=1e-7):
    #     count += 1
    #     if count > 200: break
    #   else: 
    #     count = 0
    #   prev = ds

    # if count < 200:
    X.append(dataset[i: i + window])
    Y.append(dataset[i + window: i + size])
  X.reverse()
  Y.reverse()
  return (np.array(X), np.array(Y))

# %%
x, y = chunk(normalized_ds, window, telescope, stride)
x.shape, y.shape
# Out:
# ((8351, 864, 7), (8351, 864, 7))

# %%
x.shape, y.shape
# Out:
# ((8351, 864, 7), (8351, 864, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        # axs[i].set_ylim(0,1)
    plt.show()

# %%
# shuffle data so that 
x, y = sklearn.utils.shuffle(x, y, random_state=seed)
x.shape, y.shape
# Out:
# ((8351, 864, 7), (8351, 864, 7))

# %%
inspect_multivariate(x, y, dataset.columns, telescope)

# %% [markdown]
# ## Model
# build the model and learn

# %%
input_shape = (window, 7)
output_shape = (telescope, 7)

# %%
def build_model(input_shape, output_shape):
    input = tf.keras.layers.Input(shape=input_shape)    
    conv0 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(input)
    conv1 = tfkl.MaxPool1D()(conv0)
    conv1 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(conv1)
    conv2 = tfkl.MaxPool1D()(conv1)
    conv2 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(conv2)
    conv3 = tfkl.MaxPool1D()(conv2)
    conv3 = tfkl.Conv1D(256, 3, padding='same', activation='relu')(conv3)

    lstm = tfkl.LSTM(256, dropout=0.3, return_state=True)(conv3)

    lstm_2 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(tf.keras.layers.RepeatVector(int(output_shape[0] / 4))(lstm[0]), initial_state = lstm[1:])
    out_1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_2[0])

    lstm_3 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(out_1, initial_state = lstm_2[1:])
    out_2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_3[0])

    lstm_4 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(out_2, initial_state = lstm_3[1:])
    out_3 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_4[0])

    lstm_5 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True)(out_3, initial_state = lstm_4[1:])
    out_4 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_5)

    out = tfkl.concatenate([out_1, out_2, out_3, out_4], axis=1)
    
    # dec1 = tfkl.UpSampling1D()(conv3)
    # dec1 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.Conv1D(256, 3, padding='same', activation='relu')(tfkl.concatenate([conv2, dec1], axis=2)))
    # dec2 = tfkl.UpSampling1D()(dec1)
    # dec2 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.concatenate([conv1, dec2], axis=2)))
    # dec3 = tfkl.UpSampling1D()(dec2)
    # dec4 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.concatenate([conv0, dec3], axis=2)))
    # out = tfkl.Conv1D(7, 1, padding='same', activation='relu')(dec4)

    #
    model = tf.keras.models.Model(input,out)

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])

    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 864, 7)]     0           []
#
#  conv1d_20 (Conv1D)             (None, 864, 2048)    45056       ['input_6[0][0]']
#
#  max_pooling1d_15 (MaxPooling1D  (None, 432, 2048)   0           ['conv1d_20[0][0]']
#  )
#
#  conv1d_21 (Conv1D)             (None, 432, 1024)    6292480     ['max_pooling1d_15[0][0]']
#
#  max_pooling1d_16 (MaxPooling1D  (None, 216, 1024)   0           ['conv1d_21[0][0]']
#  )
#
#  conv1d_22 (Conv1D)             (None, 216, 512)     1573376     ['max_pooling1d_16[0][0]']
#
#  max_pooling1d_17 (MaxPooling1D  (None, 108, 512)    0           ['conv1d_22[0][0]']
#  )
#
#  conv1d_23 (Conv1D)             (None, 108, 256)     393472      ['max_pooling1d_17[0][0]']
#
#  lstm_20 (LSTM)                 [(None, 256),        525312      ['conv1d_23[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  repeat_vector_5 (RepeatVector)  (None, 216, 256)    0           ['lstm_20[0][0]']
#
#  lstm_21 (LSTM)                 [(None, 216, 256),   525312      ['repeat_vector_5[0][0]',
#                                  (None, 256),                     'lstm_20[0][1]',
#                                  (None, 256)]                     'lstm_20[0][2]']
#
#  time_distributed_14 (TimeDistr  (None, 216, 7)      1799        ['lstm_21[0][0]']
#  ibuted)
#
#  lstm_22 (LSTM)                 [(None, 216, 256),   270336      ['time_distributed_14[0][0]',
#                                  (None, 256),                     'lstm_21[0][1]',
#                                  (None, 256)]                     'lstm_21[0][2]']
#
#  time_distributed_15 (TimeDistr  (None, 216, 7)      1799        ['lstm_22[0][0]']
#  ibuted)
#
#  lstm_23 (LSTM)                 [(None, 216, 256),   270336      ['time_distributed_15[0][0]',
#                                  (None, 256),                     'lstm_22[0][1]',
#                                  (None, 256)]                     'lstm_22[0][2]']
#
#  time_distributed_16 (TimeDistr  (None, 216, 7)      1799        ['lstm_23[0][0]']
#  ibuted)
#
#  lstm_24 (LSTM)                 (None, 216, 256)     270336      ['time_distributed_16[0][0]',
#                                                                   'lstm_23[0][1]',
#                                                                   'lstm_23[0][2]']
#
#  time_distributed_17 (TimeDistr  (None, 216, 7)      1799        ['lstm_24[0][0]']
#  ibuted)
#
#  concatenate_4 (Concatenate)    (None, 864, 7)       0           ['time_distributed_14[0][0]',
#                                                                   'time_distributed_15[0][0]',
#                                                                   'time_distributed_16[0][0]',
#                                                                   'time_distributed_17[0][0]']
#
# ==================================================================================================
# Total params: 10,173,212
# Trainable params: 10,173,212
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# def schedule(ind, rate):
#   if ind == 0: return rate 
#   if ind % 8 == 0:
#     return rate * 3 / 4
#   return rate
# 
# Train the model
history = model.fit(
    x = x,
    y = y,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = validation_split,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        # tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5),
        # tf.keras.callbacks.LearningRateScheduler(schedule, verbose=0),
        # tfk.callbacks.ModelCheckpoint(model_path + '_ckpt', save_best_only=True)
    ]
).history
# Out:
# Epoch 1/100
# 49/49 [==============================] - 116s 2s/step - loss: 0.0480 - mae: 0.1548 - val_loss: 0.0189 - val_mae: 0.1026
# Epoch 2/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0189 - mae: 0.1035 - val_loss: 0.0172 - val_mae: 0.0986
# Epoch 3/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0171 - mae: 0.0978 - val_loss: 0.0158 - val_mae: 0.0928
# Epoch 4/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0160 - mae: 0.0939 - val_loss: 0.0151 - val_mae: 0.0907
# Epoch 5/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0151 - mae: 0.0909 - val_loss: 0.0140 - val_mae: 0.0853
# Epoch 6/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0151 - mae: 0.0908 - val_loss: 0.0142 - val_mae: 0.0876
# Epoch 7/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0144 - mae: 0.0884 - val_loss: 0.0133 - val_mae: 0.0836
# Epoch 8/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0139 - mae: 0.0867 - val_loss: 0.0131 - val_mae: 0.0833
# Epoch 9/100
# 49/49 [==============================] - 98s 2s/step - loss: 0.0154 - mae: 0.0922 - val_loss: 0.0147 - val_mae: 0.0896
# Epoch 10/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0142 - mae: 0.0876 - val_loss: 0.0132 - val_mae: 0.0831
# Epoch 11/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0135 - mae: 0.0852 - val_loss: 0.0131 - val_mae: 0.0837
# Epoch 12/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0135 - mae: 0.0851 - val_loss: 0.0131 - val_mae: 0.0826
# Epoch 13/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0131 - mae: 0.0838 - val_loss: 0.0129 - val_mae: 0.0830
# Epoch 14/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0131 - mae: 0.0838 - val_loss: 0.0131 - val_mae: 0.0828
# Epoch 15/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0128 - mae: 0.0825 - val_loss: 0.0128 - val_mae: 0.0818
# Epoch 16/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0125 - mae: 0.0815 - val_loss: 0.0121 - val_mae: 0.0789
# Epoch 17/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0130 - mae: 0.0836 - val_loss: 0.0128 - val_mae: 0.0820
# Epoch 18/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0130 - mae: 0.0837 - val_loss: 0.0125 - val_mae: 0.0798
# Epoch 19/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0125 - mae: 0.0813 - val_loss: 0.0120 - val_mae: 0.0791
# Epoch 20/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0122 - mae: 0.0807 - val_loss: 0.0120 - val_mae: 0.0793
# Epoch 21/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0121 - mae: 0.0801 - val_loss: 0.0116 - val_mae: 0.0784
# Epoch 22/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0129 - mae: 0.0829 - val_loss: 0.0145 - val_mae: 0.0881
# Epoch 23/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0131 - mae: 0.0839 - val_loss: 0.0122 - val_mae: 0.0798
# Epoch 24/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0123 - mae: 0.0807 - val_loss: 0.0119 - val_mae: 0.0796
# Epoch 25/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0126 - mae: 0.0819 - val_loss: 0.0121 - val_mae: 0.0794
# Epoch 26/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0154 - mae: 0.0915 - val_loss: 0.0146 - val_mae: 0.0890
# Epoch 27/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0136 - mae: 0.0852 - val_loss: 0.0138 - val_mae: 0.0854
# Epoch 28/100
# 49/49 [==============================] - 96s 2s/step - loss: 0.0132 - mae: 0.0836 - val_loss: 0.0125 - val_mae: 0.0812
# Epoch 29/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0126 - mae: 0.0817 - val_loss: 0.0123 - val_mae: 0.0799
# Epoch 30/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0127 - mae: 0.0822 - val_loss: 0.0125 - val_mae: 0.0808
# Epoch 31/100
# 49/49 [==============================] - 97s 2s/step - loss: 0.0131 - mae: 0.0836 - val_loss: 0.0121 - val_mae: 0.0795

# %%
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses, lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn while saving (showing 5 of 25). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f41fe6bf850> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f41fe6e3ad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f41833bfc90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f418385ae10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f41830b5a50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model(model_path)

# %% [markdown]
# ## Analytics
# Here we compute some analytics (just to get a very rough idea: there is no test set, thus these analytics are not so good!)

# %%
X = x[100:200]
Y = y[100:200]
predictions = model.predict(X)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(Y.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(Y.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (100, 864, 7)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.011948357>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.07971541>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
inspect_multivariate_prediction(X, Y, predictions, dataset.columns, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(Y[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
reg_telescope = 864
X_test_reg, y_test_reg  = chunk(normalized_ds, window, reg_telescope, stride)
X_test_reg = X_test_reg[-10:]
y_test_reg = y_test_reg[-10:]
X_test_reg.shape, y_test_reg.shape
# Out:
# ((10, 864, 7), (10, 864, 7))

# %%
# Autoregressive Forecasting
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.016758682>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.09503819>)

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, dataset.columns, reg_telescope)
