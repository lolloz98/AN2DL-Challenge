# %%
onColab = True
model_path = './no_smooth_final_864_7'

# Decide batch size and validation split
batch_size = 128
validation_split = 0.25
epochs = 100

dataset_path = './Training.csv'

window = 300
stride = 100
# 864 / 8
telescope = 864

# %% [markdown]
# ## Init
# Initialize codalab, libraries and seed

# %%
#@title connect to codalab
if onColab:
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/MyDrive/University/ANN/CHALLENGE2
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/University/ANN/CHALLENGE2

# %%
#@title Import libraries
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import sklearn
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
#@title init seed everywhere
seed = 32

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ## Dataset import and manipulation

# %%
dataset  = pd.read_csv(dataset_path)
print(dataset.shape)
dataset.describe()
# Out:
# (68528, 7)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       6.094102      4.695539  ...          23.237929      8.231283
# std        1.941639      3.374224  ...          14.298260     11.285101
# min       -0.972080     -8.450380  ...          -6.006860    -42.769221
# 25%        4.791440      2.223420  ...          12.560240      6.604160
# 50%        5.702780      4.668600  ...          20.151420     10.968300
# 75%        7.067300      7.115440  ...          31.245199     15.334100
# max       15.106680     18.122899  ...          77.371620     31.024420
#
# [8 rows x 7 columns]

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
# inspect_dataframe(dataset, dataset.columns)

# %%
def normalize(dataset, t=None):
  if t is None or t == 'minmax':
    x_min = dataset.min(axis=0)
    print(x_min.shape)
    x_max = dataset.max()
    nd = (dataset - x_min) / (x_max - x_min)
    return nd
  elif t == 'mean_std':
    x_mean = dataset.mean()
    x_std = dataset.std()
    nd = (dataset - x_mean) / x_std
    return nd

# %%
# dataset = dataset[['Sponginess', 'Crunchiness', 'Hype root']]
# dataset.describe()

# %%
normalized_ds = normalize(dataset)
normalized_ds.describe()
# Out:
# (7,)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       0.439473      0.494704  ...           0.350747      0.691123
# std        0.120758      0.126978  ...           0.171486      0.152928
# min        0.000000      0.000000  ...           0.000000      0.000000
# 25%        0.358455      0.401674  ...           0.222685      0.669074
# 50%        0.415135      0.493691  ...           0.313729      0.728213
# 75%        0.500000      0.585770  ...           0.446783      0.787376
# max        1.000000      1.000000  ...           1.000000      1.000000
#
# [8 rows x 7 columns]

# %%
import math
def chunk(dataset, window, telescope, stride):
  """
  divide the dataset in chunks. 
  It keeps the right-most elements and discard the left ones, if size and stride are not compatible with dimensions. 
  """
  size = window + telescope
  X = []
  Y = []
  for i in range(len(dataset) - size, -1, -stride):
    
    # count = 0
    # prev = 0
    # for ds in dataset.filter(range(i, i + size), axis=0)['Crunchiness']:
    #   if math.isclose(prev, ds, rel_tol=1e-7):
    #     count += 1
    #     if count > 200: break
    #   else: 
    #     count = 0
    #   prev = ds

    # if count < 200:
    X.append(dataset[i: i + window])
    Y.append(dataset[i + window: i + size])
  X.reverse()
  Y.reverse()
  return (np.array(X), np.array(Y))

# %%
x, y = chunk(normalized_ds, window, telescope, stride)
x.shape, y.shape
# Out:
# ((674, 300, 7), (674, 864, 7))

# %%
x.shape, y.shape
# Out:
# ((674, 300, 7), (674, 864, 7))

# %%
import sklearn

# %%
# delete similar
from sklearn.metrics import mean_squared_error
i = 0
while True:
  if i >= len(x): break
  to_del = []
  for j in range(i, len(x)):
    if(i != j):
      curr = mean_squared_error(np.concatenate((x[i],y[i])), np.concatenate((x[j],y[j])))
      if curr < 0.01:
        to_del.append(j)
  i += 1
  x = np.delete(x, to_del,axis=0)
  y = np.delete(y, to_del,axis=0)
x.shape, y.shape
# Out:
# ((318, 300, 7), (318, 864, 7))

# %%
# repeat a lot of them -> we handle 'series imbalance'
rep = 20
x = np.repeat(x, rep, axis=0)
y = np.repeat(y, rep, axis=0)
x.shape, y.shape
# Out:
# ((6360, 300, 7), (6360, 864, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        # axs[i].set_ylim(0,1)
    plt.show()

# %%
# shuffle data so that 
x, y = sklearn.utils.shuffle(x, y, random_state=seed)
x.shape, y.shape
# Out:
# ((6360, 300, 7), (6360, 864, 7))

# %%
inspect_multivariate(x, y, dataset.columns, telescope)

# %% [markdown]
# ## Model
# build the model and learn

# %%
input_shape = (window, 7)
output_shape = (telescope, 7)

# %%
def build_model(input_shape, output_shape):
    input = tf.keras.layers.Input(shape=input_shape)    
    conv0 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(input)
    conv1 = tfkl.MaxPool1D()(conv0)
    conv1 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(conv1)
    conv2 = tfkl.MaxPool1D()(conv1)
    conv2 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(conv2)
    conv3 = tfkl.MaxPool1D()(conv2)
    conv3 = tfkl.Conv1D(256, 3, padding='same', activation='relu')(conv3)

    lstm = tfkl.LSTM(256, dropout=0.3, return_state=True)(conv3)

    lstm_2 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(tf.keras.layers.RepeatVector(int(output_shape[0] / 4))(lstm[0]), initial_state = lstm[1:])
    # out_1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_2[0])

    lstm_3 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(lstm_2[0], initial_state = lstm_2[1:])
    # out_2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_3[0])

    lstm_4 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(lstm_3[0], initial_state = lstm_3[1:])
    # out_3 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_4[0])

    lstm_5 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True)(lstm_4[0], initial_state = lstm_4[1:])
    # out_4 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_5)

    out = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(tfkl.concatenate([lstm_2[0], lstm_3[0], lstm_4[0], lstm_5], axis=1))
    
    # dec1 = tfkl.UpSampling1D()(conv3)
    # dec1 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.Conv1D(256, 3, padding='same', activation='relu')(tfkl.concatenate([conv2, dec1], axis=2)))
    # dec2 = tfkl.UpSampling1D()(dec1)
    # dec2 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.concatenate([conv1, dec2], axis=2)))
    # dec3 = tfkl.UpSampling1D()(dec2)
    # dec4 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.concatenate([conv0, dec3], axis=2)))
    # out = tfkl.Conv1D(7, 1, padding='same', activation='relu')(dec4)

    #
    model = tf.keras.models.Model(input,out)

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])

    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 300, 7)]     0           []
#
#  conv1d_4 (Conv1D)              (None, 300, 2048)    45056       ['input_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 150, 2048)   0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 150, 1024)    6292480     ['max_pooling1d_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 75, 1024)    0           ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 75, 512)      1573376     ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 37, 512)     0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 37, 256)      393472      ['max_pooling1d_5[0][0]']
#
#  lstm_5 (LSTM)                  [(None, 256),        525312      ['conv1d_7[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  repeat_vector_1 (RepeatVector)  (None, 216, 256)    0           ['lstm_5[0][0]']
#
#  lstm_6 (LSTM)                  [(None, 216, 256),   525312      ['repeat_vector_1[0][0]',
#                                  (None, 256),                     'lstm_5[0][1]',
#                                  (None, 256)]                     'lstm_5[0][2]']
#
#  lstm_7 (LSTM)                  [(None, 216, 256),   525312      ['lstm_6[0][0]',
#                                  (None, 256),                     'lstm_6[0][1]',
#                                  (None, 256)]                     'lstm_6[0][2]']
#
#  lstm_8 (LSTM)                  [(None, 216, 256),   525312      ['lstm_7[0][0]',
#                                  (None, 256),                     'lstm_7[0][1]',
#                                  (None, 256)]                     'lstm_7[0][2]']
#
#  lstm_9 (LSTM)                  (None, 216, 256)     525312      ['lstm_8[0][0]',
#                                                                   'lstm_8[0][1]',
#                                                                   'lstm_8[0][2]']
#
#  concatenate_1 (Concatenate)    (None, 864, 256)     0           ['lstm_6[0][0]',
#                                                                   'lstm_7[0][0]',
#                                                                   'lstm_8[0][0]',
#                                                                   'lstm_9[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 864, 7)      1799        ['concatenate_1[0][0]']
#  buted)
#
# ==================================================================================================
# Total params: 10,932,743
# Trainable params: 10,932,743
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# def schedule(ind, rate):
#   if ind == 0: return rate 
#   if ind % 8 == 0:
#     return rate * 3 / 4
#   return rate
# 
# Train the model
history = model.fit(
    x = x,
    y = y,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = validation_split,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        # tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5),
        # tf.keras.callbacks.LearningRateScheduler(schedule, verbose=0),
        # tfk.callbacks.ModelCheckpoint(model_path + '_ckpt', save_best_only=True)
    ]
).history
# Out:
# Epoch 1/100
# 38/38 [==============================] - 55s 1s/step - loss: 0.0435 - mae: 0.1499 - val_loss: 0.0215 - val_mae: 0.1101
# Epoch 2/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0214 - mae: 0.1102 - val_loss: 0.0206 - val_mae: 0.1089
# Epoch 3/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0202 - mae: 0.1070 - val_loss: 0.0179 - val_mae: 0.1001
# Epoch 4/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0178 - mae: 0.0994 - val_loss: 0.0172 - val_mae: 0.0970
# Epoch 5/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0168 - mae: 0.0962 - val_loss: 0.0158 - val_mae: 0.0920
# Epoch 6/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0157 - mae: 0.0924 - val_loss: 0.0151 - val_mae: 0.0903
# Epoch 7/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0153 - mae: 0.0911 - val_loss: 0.0147 - val_mae: 0.0891
# Epoch 8/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0146 - mae: 0.0888 - val_loss: 0.0140 - val_mae: 0.0851
# Epoch 9/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0143 - mae: 0.0878 - val_loss: 0.0135 - val_mae: 0.0847
# Epoch 10/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0138 - mae: 0.0860 - val_loss: 0.0132 - val_mae: 0.0840
# Epoch 11/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0136 - mae: 0.0858 - val_loss: 0.0129 - val_mae: 0.0822
# Epoch 12/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0129 - mae: 0.0831 - val_loss: 0.0138 - val_mae: 0.0868
# Epoch 13/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0134 - mae: 0.0849 - val_loss: 0.0124 - val_mae: 0.0806
# Epoch 14/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0125 - mae: 0.0816 - val_loss: 0.0124 - val_mae: 0.0807
# Epoch 15/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0123 - mae: 0.0809 - val_loss: 0.0118 - val_mae: 0.0776
# Epoch 16/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0121 - mae: 0.0800 - val_loss: 0.0129 - val_mae: 0.0812
# Epoch 17/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0122 - mae: 0.0802 - val_loss: 0.0116 - val_mae: 0.0773
# Epoch 18/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0116 - mae: 0.0779 - val_loss: 0.0112 - val_mae: 0.0759
# Epoch 19/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0114 - mae: 0.0770 - val_loss: 0.0111 - val_mae: 0.0753
# Epoch 20/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0112 - mae: 0.0766 - val_loss: 0.0107 - val_mae: 0.0732
# Epoch 21/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0110 - mae: 0.0757 - val_loss: 0.0116 - val_mae: 0.0774
# Epoch 22/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0112 - mae: 0.0766 - val_loss: 0.0098 - val_mae: 0.0707
# Epoch 23/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0093 - mae: 0.0704 - val_loss: 0.0083 - val_mae: 0.0667
# Epoch 24/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0079 - mae: 0.0650 - val_loss: 0.0072 - val_mae: 0.0615
# Epoch 25/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0073 - mae: 0.0620 - val_loss: 0.0067 - val_mae: 0.0592
# Epoch 26/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0069 - mae: 0.0602 - val_loss: 0.0063 - val_mae: 0.0566
# Epoch 27/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0066 - mae: 0.0586 - val_loss: 0.0062 - val_mae: 0.0560
# Epoch 28/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0066 - mae: 0.0584 - val_loss: 0.0065 - val_mae: 0.0570
# Epoch 29/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0063 - mae: 0.0567 - val_loss: 0.0058 - val_mae: 0.0539
# Epoch 30/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0059 - mae: 0.0551 - val_loss: 0.0054 - val_mae: 0.0516
# Epoch 31/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0057 - mae: 0.0537 - val_loss: 0.0052 - val_mae: 0.0508
# Epoch 32/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0056 - mae: 0.0532 - val_loss: 0.0056 - val_mae: 0.0523
# Epoch 33/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0054 - mae: 0.0525 - val_loss: 0.0050 - val_mae: 0.0501
# Epoch 34/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0054 - mae: 0.0522 - val_loss: 0.0047 - val_mae: 0.0481
# Epoch 35/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0051 - mae: 0.0505 - val_loss: 0.0049 - val_mae: 0.0488
# Epoch 36/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0049 - mae: 0.0498 - val_loss: 0.0045 - val_mae: 0.0475
# Epoch 37/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0048 - mae: 0.0494 - val_loss: 0.0044 - val_mae: 0.0466
# Epoch 38/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0048 - mae: 0.0492 - val_loss: 0.0051 - val_mae: 0.0496
# Epoch 39/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0045 - mae: 0.0481 - val_loss: 0.0041 - val_mae: 0.0456
# Epoch 40/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0063 - mae: 0.0572 - val_loss: 0.0066 - val_mae: 0.0591
# Epoch 41/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0052 - mae: 0.0526 - val_loss: 0.0044 - val_mae: 0.0478
# Epoch 42/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0042 - mae: 0.0468 - val_loss: 0.0035 - val_mae: 0.0426
# Epoch 43/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0037 - mae: 0.0442 - val_loss: 0.0034 - val_mae: 0.0421
# Epoch 44/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0035 - mae: 0.0428 - val_loss: 0.0033 - val_mae: 0.0416
# Epoch 45/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0034 - mae: 0.0422 - val_loss: 0.0031 - val_mae: 0.0398
# Epoch 46/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0033 - mae: 0.0415 - val_loss: 0.0031 - val_mae: 0.0401
# Epoch 47/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0032 - mae: 0.0411 - val_loss: 0.0030 - val_mae: 0.0392
# Epoch 48/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0031 - mae: 0.0407 - val_loss: 0.0030 - val_mae: 0.0391
# Epoch 49/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0030 - mae: 0.0402 - val_loss: 0.0028 - val_mae: 0.0380
# Epoch 50/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0031 - mae: 0.0406 - val_loss: 0.0029 - val_mae: 0.0385
# Epoch 51/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0031 - mae: 0.0406 - val_loss: 0.0027 - val_mae: 0.0376
# Epoch 52/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0028 - mae: 0.0387 - val_loss: 0.0025 - val_mae: 0.0364
# Epoch 53/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0027 - mae: 0.0381 - val_loss: 0.0025 - val_mae: 0.0357
# Epoch 54/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0027 - mae: 0.0376 - val_loss: 0.0024 - val_mae: 0.0356
# Epoch 55/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0026 - mae: 0.0371 - val_loss: 0.0024 - val_mae: 0.0357
# Epoch 56/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0026 - mae: 0.0372 - val_loss: 0.0022 - val_mae: 0.0341
# Epoch 57/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0025 - mae: 0.0363 - val_loss: 0.0022 - val_mae: 0.0338
# Epoch 58/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0024 - mae: 0.0360 - val_loss: 0.0026 - val_mae: 0.0362
# Epoch 59/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0025 - mae: 0.0360 - val_loss: 0.0023 - val_mae: 0.0342
# Epoch 60/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0025 - mae: 0.0364 - val_loss: 0.0024 - val_mae: 0.0355
# Epoch 61/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0024 - mae: 0.0355 - val_loss: 0.0021 - val_mae: 0.0327
# Epoch 62/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0023 - mae: 0.0347 - val_loss: 0.0021 - val_mae: 0.0327
# Epoch 63/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0023 - mae: 0.0348 - val_loss: 0.0020 - val_mae: 0.0320
# Epoch 64/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0022 - mae: 0.0344 - val_loss: 0.0022 - val_mae: 0.0333
# Epoch 65/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0022 - mae: 0.0341 - val_loss: 0.0020 - val_mae: 0.0317
# Epoch 66/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0018 - val_mae: 0.0305
# Epoch 67/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0019 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0302
# Epoch 68/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0020 - mae: 0.0327 - val_loss: 0.0017 - val_mae: 0.0300
# Epoch 69/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0020 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0308
# Epoch 70/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0022 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0315
# Epoch 71/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0017 - val_mae: 0.0296
# Epoch 72/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0045 - mae: 0.0442 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 73/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0067 - mae: 0.0600 - val_loss: 0.0044 - val_mae: 0.0488
# Epoch 74/100
# 38/38 [==============================] - 38s 1s/step - loss: 0.0037 - mae: 0.0441 - val_loss: 0.0026 - val_mae: 0.0371
# Epoch 75/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0025 - mae: 0.0365 - val_loss: 0.0019 - val_mae: 0.0317
# Epoch 76/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0021 - mae: 0.0335 - val_loss: 0.0018 - val_mae: 0.0306
# Epoch 77/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0019 - mae: 0.0320 - val_loss: 0.0019 - val_mae: 0.0312
# Epoch 78/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0018 - mae: 0.0313 - val_loss: 0.0018 - val_mae: 0.0304
# Epoch 79/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0018 - mae: 0.0306 - val_loss: 0.0016 - val_mae: 0.0285
# Epoch 80/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0016 - val_mae: 0.0289
# Epoch 81/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0017 - mae: 0.0300 - val_loss: 0.0017 - val_mae: 0.0288
# Epoch 82/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0017 - mae: 0.0297 - val_loss: 0.0015 - val_mae: 0.0274
# Epoch 83/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0016 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0269
# Epoch 84/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0016 - mae: 0.0289 - val_loss: 0.0014 - val_mae: 0.0269
# Epoch 85/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0014 - val_mae: 0.0267
# Epoch 86/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0015 - val_mae: 0.0270
# Epoch 87/100
# 38/38 [==============================] - 38s 1s/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0014 - val_mae: 0.0264
# Epoch 88/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0016 - mae: 0.0285 - val_loss: 0.0014 - val_mae: 0.0265
# Epoch 89/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0283 - val_loss: 0.0013 - val_mae: 0.0255
# Epoch 90/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0280 - val_loss: 0.0014 - val_mae: 0.0263
# Epoch 91/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0013 - val_mae: 0.0258
# Epoch 92/100
# 38/38 [==============================] - 38s 1s/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0014 - val_mae: 0.0260
# Epoch 93/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0278 - val_loss: 0.0013 - val_mae: 0.0251
# Epoch 94/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0014 - mae: 0.0273 - val_loss: 0.0013 - val_mae: 0.0252
# Epoch 95/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0015 - val_mae: 0.0272
# Epoch 96/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0013 - val_mae: 0.0254
# Epoch 97/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0014 - mae: 0.0269 - val_loss: 0.0015 - val_mae: 0.0266
# Epoch 98/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0014 - mae: 0.0267 - val_loss: 0.0013 - val_mae: 0.0254
# Epoch 99/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0014 - mae: 0.0263 - val_loss: 0.0012 - val_mae: 0.0245
# Epoch 100/100
# 38/38 [==============================] - 39s 1s/step - loss: 0.0014 - mae: 0.0264 - val_loss: 0.0012 - val_mae: 0.0246

# %%
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn, lstm_cell_11_layer_call_and_return_conditional_losses, lstm_cell_12_layer_call_fn while saving (showing 5 of 25). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f26fa456590> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2781ccb210> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f26fa631f50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f26fa392110> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f26fa5f3690> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model(model_path)

# %% [markdown]
# ## Analytics
# Here we compute some analytics (just to get a very rough idea: there is no test set, thus these analytics are not so good!)

# %%
X = x[100:200]
Y = y[100:200]
predictions = model.predict(X)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(Y.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(Y.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (100, 864, 7)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.001168683>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.023873856>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
inspect_multivariate_prediction(X, Y, predictions, dataset.columns, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(Y[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
reg_telescope = 864
X_test_reg, y_test_reg  = chunk(normalized_ds, window, reg_telescope, stride)
X_test_reg = X_test_reg[-10:]
y_test_reg = y_test_reg[-10:]
X_test_reg.shape, y_test_reg.shape
# Out:
# ((10, 300, 7), (10, 864, 7))

# %%
# Autoregressive Forecasting
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.0046650134>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.04075448>)

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, dataset.columns, reg_telescope)
