# %%
onColab = True
model_path = './inno_training_no_smooth_final_864_3'

# Decide batch size and validation split
batch_size = 128
validation_split = 0.25
epochs = 100

dataset_path = './Training.csv'

window = 300
stride = 10
# 864 / 8
telescope = 864

# %% [markdown]
# ## Init
# Initialize codalab, libraries and seed

# %%
#@title connect to codalab
if onColab:
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/MyDrive/University/ANN/CHALLENGE2
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/University/ANN/CHALLENGE2

# %%
#@title Import libraries
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import sklearn
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
#@title init seed everywhere
seed = 32

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ## Dataset import and manipulation

# %%
dataset  = pd.read_csv(dataset_path)
print(dataset.shape)
dataset.describe()
# Out:
# (68528, 7)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       6.094102      4.695539  ...          23.237929      8.231283
# std        1.941639      3.374224  ...          14.298260     11.285101
# min       -0.972080     -8.450380  ...          -6.006860    -42.769221
# 25%        4.791440      2.223420  ...          12.560240      6.604160
# 50%        5.702780      4.668600  ...          20.151420     10.968300
# 75%        7.067300      7.115440  ...          31.245199     15.334100
# max       15.106680     18.122899  ...          77.371620     31.024420
#
# [8 rows x 7 columns]

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
# inspect_dataframe(dataset, dataset.columns)

# %%
def normalize(dataset, t=None):
  if t is None or t == 'minmax':
    x_min = dataset.min(axis=0)
    print(x_min.shape)
    x_max = dataset.max()
    nd = (dataset - x_min) / (x_max - x_min)
    return nd
  elif t == 'mean_std':
    x_mean = dataset.mean()
    x_std = dataset.std()
    nd = (dataset - x_mean) / x_std
    return nd

# %%
# dataset = dataset[['Sponginess', 'Crunchiness', 'Hype root']]
# dataset.describe()

# %%
normalized_ds = normalize(dataset)
normalized_ds.describe()
# Out:
# (7,)
#          Sponginess  Wonder level  ...  Soap slipperiness     Hype root
# count  68528.000000  68528.000000  ...       68528.000000  68528.000000
# mean       0.439473      0.494704  ...           0.350747      0.691123
# std        0.120758      0.126978  ...           0.171486      0.152928
# min        0.000000      0.000000  ...           0.000000      0.000000
# 25%        0.358455      0.401674  ...           0.222685      0.669074
# 50%        0.415135      0.493691  ...           0.313729      0.728213
# 75%        0.500000      0.585770  ...           0.446783      0.787376
# max        1.000000      1.000000  ...           1.000000      1.000000
#
# [8 rows x 7 columns]

# %%
import math
def chunk(dataset, window, telescope, stride):
  """
  divide the dataset in chunks. 
  It keeps the right-most elements and discard the left ones, if size and stride are not compatible with dimensions. 
  """
  size = window + telescope
  X = []
  Y = []
  for i in range(len(dataset) - size, -1, -stride):
    
    # count = 0
    # prev = 0
    # for ds in dataset.filter(range(i, i + size), axis=0)['Crunchiness']:
    #   if math.isclose(prev, ds, rel_tol=1e-7):
    #     count += 1
    #     if count > 200: break
    #   else: 
    #     count = 0
    #   prev = ds

    # if count < 200:
    X.append(dataset[i: i + window])
    Y.append(dataset[i + window: i + size])
  X.reverse()
  Y.reverse()
  return (np.array(X), np.array(Y))

# %%
x, y = chunk(normalized_ds, window, telescope, stride)
x.shape, y.shape
# Out:
# ((6737, 300, 7), (6737, 864, 7))

# %%
x.shape, y.shape
# Out:
# ((6737, 300, 7), (6737, 864, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        # axs[i].set_ylim(0,1)
    plt.show()

# %%
# shuffle data so that 
x, y = sklearn.utils.shuffle(x, y, random_state=seed)
x.shape, y.shape
# Out:
# ((6737, 300, 7), (6737, 864, 7))

# %%
inspect_multivariate(x, y, dataset.columns, telescope)

# %% [markdown]
# ## Model
# build the model and learn

# %%
input_shape = (window, 7)
output_shape = (telescope, 7)

# %%
def build_model(input_shape, output_shape):
    input = tf.keras.layers.Input(shape=input_shape)    
    conv0 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(input)
    conv1 = tfkl.MaxPool1D()(conv0)
    conv1 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(conv1)
    conv2 = tfkl.MaxPool1D()(conv1)
    conv2 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(conv2)
    conv3 = tfkl.MaxPool1D()(conv2)
    conv3 = tfkl.Conv1D(256, 3, padding='same', activation='relu')(conv3)

    lstm = tfkl.LSTM(256, dropout=0.3, return_state=True)(conv3)

    lstm_2 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(tf.keras.layers.RepeatVector(int(output_shape[0] / 4))(lstm[0]), initial_state = lstm[1:])
    # out_1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_2[0])

    lstm_3 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(lstm_2[0], initial_state = lstm_2[1:])
    # out_2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_3[0])

    lstm_4 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True, return_state=True)(lstm_3[0], initial_state = lstm_3[1:])
    # out_3 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_4[0])

    lstm_5 = tf.keras.layers.LSTM(256, dropout=0.3, return_sequences=True)(lstm_4[0], initial_state = lstm_4[1:])
    # out_4 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(lstm_5)

    out = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(input_shape[1]))(tfkl.concatenate([lstm_2[0], lstm_3[0], lstm_4[0], lstm_5], axis=1))
    
    # dec1 = tfkl.UpSampling1D()(conv3)
    # dec1 = tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.Conv1D(256, 3, padding='same', activation='relu')(tfkl.concatenate([conv2, dec1], axis=2)))
    # dec2 = tfkl.UpSampling1D()(dec1)
    # dec2 = tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.Conv1D(512, 3, padding='same', activation='relu')(tfkl.concatenate([conv1, dec2], axis=2)))
    # dec3 = tfkl.UpSampling1D()(dec2)
    # dec4 = tfkl.Conv1D(2048, 3, padding='same', activation='relu')(tfkl.Conv1D(1024, 3, padding='same', activation='relu')(tfkl.concatenate([conv0, dec3], axis=2)))
    # out = tfkl.Conv1D(7, 1, padding='same', activation='relu')(dec4)

    #
    model = tf.keras.models.Model(input,out)

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])

    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 300, 7)]     0           []
#
#  conv1d_24 (Conv1D)             (None, 300, 2048)    45056       ['input_7[0][0]']
#
#  max_pooling1d_18 (MaxPooling1D  (None, 150, 2048)   0           ['conv1d_24[0][0]']
#  )
#
#  conv1d_25 (Conv1D)             (None, 150, 1024)    6292480     ['max_pooling1d_18[0][0]']
#
#  max_pooling1d_19 (MaxPooling1D  (None, 75, 1024)    0           ['conv1d_25[0][0]']
#  )
#
#  conv1d_26 (Conv1D)             (None, 75, 512)      1573376     ['max_pooling1d_19[0][0]']
#
#  max_pooling1d_20 (MaxPooling1D  (None, 37, 512)     0           ['conv1d_26[0][0]']
#  )
#
#  conv1d_27 (Conv1D)             (None, 37, 256)      393472      ['max_pooling1d_20[0][0]']
#
#  lstm_28 (LSTM)                 [(None, 256),        525312      ['conv1d_27[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  repeat_vector_7 (RepeatVector)  (None, 216, 256)    0           ['lstm_28[0][0]']
#
#  lstm_29 (LSTM)                 [(None, 216, 256),   525312      ['repeat_vector_7[0][0]',
#                                  (None, 256),                     'lstm_28[0][1]',
#                                  (None, 256)]                     'lstm_28[0][2]']
#
#  lstm_30 (LSTM)                 [(None, 216, 256),   525312      ['lstm_29[0][0]',
#                                  (None, 256),                     'lstm_29[0][1]',
#                                  (None, 256)]                     'lstm_29[0][2]']
#
#  lstm_31 (LSTM)                 [(None, 216, 256),   525312      ['lstm_30[0][0]',
#                                  (None, 256),                     'lstm_30[0][1]',
#                                  (None, 256)]                     'lstm_30[0][2]']
#
#  lstm_32 (LSTM)                 (None, 216, 256)     525312      ['lstm_31[0][0]',
#                                                                   'lstm_31[0][1]',
#                                                                   'lstm_31[0][2]']
#
#  concatenate_5 (Concatenate)    (None, 864, 256)     0           ['lstm_29[0][0]',
#                                                                   'lstm_30[0][0]',
#                                                                   'lstm_31[0][0]',
#                                                                   'lstm_32[0][0]']
#
#  time_distributed_18 (TimeDistr  (None, 864, 7)      1799        ['concatenate_5[0][0]']
#  ibuted)
#
# ==================================================================================================
# Total params: 10,932,743
# Trainable params: 10,932,743
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# def schedule(ind, rate):
#   if ind == 0: return rate 
#   if ind % 8 == 0:
#     return rate * 3 / 4
#   return rate
# 
# Train the model
history = model.fit(
    x = x,
    y = y,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = validation_split,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        # tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5),
        # tf.keras.callbacks.LearningRateScheduler(schedule, verbose=0),
        # tfk.callbacks.ModelCheckpoint(model_path + '_ckpt', save_best_only=True)
    ]
).history
# Out:
# Epoch 1/100
# 40/40 [==============================] - 69s 491ms/step - loss: 0.0444 - mae: 0.1496 - val_loss: 0.0203 - val_mae: 0.1054
# Epoch 2/100
# 40/40 [==============================] - 18s 462ms/step - loss: 0.0203 - mae: 0.1070 - val_loss: 0.0186 - val_mae: 0.1023
# Epoch 3/100
# 40/40 [==============================] - 18s 460ms/step - loss: 0.0179 - mae: 0.1002 - val_loss: 0.0167 - val_mae: 0.0966
# Epoch 4/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0162 - mae: 0.0947 - val_loss: 0.0148 - val_mae: 0.0898
# Epoch 5/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0149 - mae: 0.0901 - val_loss: 0.0145 - val_mae: 0.0890
# Epoch 6/100
# 40/40 [==============================] - 18s 454ms/step - loss: 0.0139 - mae: 0.0863 - val_loss: 0.0131 - val_mae: 0.0823
# Epoch 7/100
# 40/40 [==============================] - 18s 455ms/step - loss: 0.0132 - mae: 0.0835 - val_loss: 0.0132 - val_mae: 0.0812
# Epoch 8/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0129 - mae: 0.0823 - val_loss: 0.0127 - val_mae: 0.0812
# Epoch 9/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0125 - mae: 0.0813 - val_loss: 0.0127 - val_mae: 0.0809
# Epoch 10/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0124 - mae: 0.0806 - val_loss: 0.0119 - val_mae: 0.0790
# Epoch 11/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0120 - mae: 0.0793 - val_loss: 0.0120 - val_mae: 0.0786
# Epoch 12/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0119 - mae: 0.0790 - val_loss: 0.0115 - val_mae: 0.0769
# Epoch 13/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0119 - mae: 0.0791 - val_loss: 0.0115 - val_mae: 0.0772
# Epoch 14/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0116 - mae: 0.0781 - val_loss: 0.0119 - val_mae: 0.0773
# Epoch 15/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0115 - mae: 0.0776 - val_loss: 0.0115 - val_mae: 0.0782
# Epoch 16/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0117 - mae: 0.0785 - val_loss: 0.0117 - val_mae: 0.0775
# Epoch 17/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0116 - mae: 0.0781 - val_loss: 0.0112 - val_mae: 0.0750
# Epoch 18/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0111 - mae: 0.0761 - val_loss: 0.0110 - val_mae: 0.0749
# Epoch 19/100
# 40/40 [==============================] - 18s 455ms/step - loss: 0.0110 - mae: 0.0759 - val_loss: 0.0109 - val_mae: 0.0765
# Epoch 20/100
# 40/40 [==============================] - 18s 454ms/step - loss: 0.0109 - mae: 0.0756 - val_loss: 0.0110 - val_mae: 0.0753
# Epoch 21/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0108 - mae: 0.0750 - val_loss: 0.0108 - val_mae: 0.0745
# Epoch 22/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0107 - mae: 0.0746 - val_loss: 0.0107 - val_mae: 0.0745
# Epoch 23/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0107 - mae: 0.0748 - val_loss: 0.0108 - val_mae: 0.0746
# Epoch 24/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0113 - mae: 0.0771 - val_loss: 0.0116 - val_mae: 0.0786
# Epoch 25/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0108 - mae: 0.0755 - val_loss: 0.0104 - val_mae: 0.0731
# Epoch 26/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0104 - mae: 0.0733 - val_loss: 0.0104 - val_mae: 0.0734
# Epoch 27/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0104 - mae: 0.0732 - val_loss: 0.0102 - val_mae: 0.0729
# Epoch 28/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0103 - mae: 0.0730 - val_loss: 0.0102 - val_mae: 0.0725
# Epoch 29/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0102 - mae: 0.0726 - val_loss: 0.0099 - val_mae: 0.0707
# Epoch 30/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0100 - mae: 0.0717 - val_loss: 0.0100 - val_mae: 0.0712
# Epoch 31/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0101 - mae: 0.0722 - val_loss: 0.0098 - val_mae: 0.0711
# Epoch 32/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0104 - mae: 0.0733 - val_loss: 0.0103 - val_mae: 0.0735
# Epoch 33/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0100 - mae: 0.0717 - val_loss: 0.0098 - val_mae: 0.0713
# Epoch 34/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0097 - mae: 0.0705 - val_loss: 0.0096 - val_mae: 0.0698
# Epoch 35/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0096 - mae: 0.0702 - val_loss: 0.0092 - val_mae: 0.0686
# Epoch 36/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0094 - mae: 0.0698 - val_loss: 0.0087 - val_mae: 0.0675
# Epoch 37/100
# 40/40 [==============================] - 18s 453ms/step - loss: 0.0084 - mae: 0.0664 - val_loss: 0.0078 - val_mae: 0.0636
# Epoch 38/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0089 - mae: 0.0685 - val_loss: 0.0085 - val_mae: 0.0670
# Epoch 39/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0079 - mae: 0.0645 - val_loss: 0.0077 - val_mae: 0.0637
# Epoch 40/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0073 - mae: 0.0620 - val_loss: 0.0069 - val_mae: 0.0600
# Epoch 41/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0071 - mae: 0.0609 - val_loss: 0.0066 - val_mae: 0.0588
# Epoch 42/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0066 - mae: 0.0588 - val_loss: 0.0064 - val_mae: 0.0575
# Epoch 43/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0064 - mae: 0.0580 - val_loss: 0.0060 - val_mae: 0.0556
# Epoch 44/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0065 - mae: 0.0580 - val_loss: 0.0061 - val_mae: 0.0564
# Epoch 45/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0061 - mae: 0.0563 - val_loss: 0.0058 - val_mae: 0.0542
# Epoch 46/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0058 - mae: 0.0547 - val_loss: 0.0056 - val_mae: 0.0530
# Epoch 47/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0057 - mae: 0.0540 - val_loss: 0.0056 - val_mae: 0.0534
# Epoch 48/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0055 - mae: 0.0531 - val_loss: 0.0053 - val_mae: 0.0519
# Epoch 49/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0056 - mae: 0.0533 - val_loss: 0.0053 - val_mae: 0.0518
# Epoch 50/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0054 - mae: 0.0526 - val_loss: 0.0052 - val_mae: 0.0513
# Epoch 51/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0052 - mae: 0.0517 - val_loss: 0.0051 - val_mae: 0.0509
# Epoch 52/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0051 - mae: 0.0516 - val_loss: 0.0050 - val_mae: 0.0503
# Epoch 53/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0049 - mae: 0.0503 - val_loss: 0.0047 - val_mae: 0.0492
# Epoch 54/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0048 - mae: 0.0503 - val_loss: 0.0046 - val_mae: 0.0492
# Epoch 55/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0046 - mae: 0.0488 - val_loss: 0.0043 - val_mae: 0.0471
# Epoch 56/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0044 - mae: 0.0479 - val_loss: 0.0042 - val_mae: 0.0466
# Epoch 57/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0043 - mae: 0.0474 - val_loss: 0.0042 - val_mae: 0.0462
# Epoch 58/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0042 - mae: 0.0470 - val_loss: 0.0042 - val_mae: 0.0462
# Epoch 59/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0050 - mae: 0.0510 - val_loss: 0.0054 - val_mae: 0.0525
# Epoch 60/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0049 - mae: 0.0506 - val_loss: 0.0045 - val_mae: 0.0482
# Epoch 61/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0043 - mae: 0.0472 - val_loss: 0.0046 - val_mae: 0.0483
# Epoch 62/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0041 - mae: 0.0460 - val_loss: 0.0039 - val_mae: 0.0447
# Epoch 63/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0040 - mae: 0.0453 - val_loss: 0.0039 - val_mae: 0.0445
# Epoch 64/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0039 - mae: 0.0450 - val_loss: 0.0037 - val_mae: 0.0438
# Epoch 65/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0038 - mae: 0.0443 - val_loss: 0.0037 - val_mae: 0.0436
# Epoch 66/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0038 - mae: 0.0443 - val_loss: 0.0036 - val_mae: 0.0429
# Epoch 67/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0037 - mae: 0.0439 - val_loss: 0.0036 - val_mae: 0.0431
# Epoch 68/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0036 - mae: 0.0431 - val_loss: 0.0036 - val_mae: 0.0431
# Epoch 69/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0036 - mae: 0.0432 - val_loss: 0.0035 - val_mae: 0.0424
# Epoch 70/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.0037 - mae: 0.0436 - val_loss: 0.0035 - val_mae: 0.0422
# Epoch 71/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0036 - mae: 0.0429 - val_loss: 0.0034 - val_mae: 0.0416
# Epoch 72/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0035 - mae: 0.0425 - val_loss: 0.0034 - val_mae: 0.0418
# Epoch 73/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0035 - mae: 0.0426 - val_loss: 0.0034 - val_mae: 0.0418
# Epoch 74/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0034 - mae: 0.0420 - val_loss: 0.0036 - val_mae: 0.0427
# Epoch 75/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0039 - mae: 0.0442 - val_loss: 0.0053 - val_mae: 0.0523
# Epoch 76/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0089 - mae: 0.0689 - val_loss: 0.0077 - val_mae: 0.0635
# Epoch 77/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0070 - mae: 0.0606 - val_loss: 0.0060 - val_mae: 0.0551
# Epoch 78/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0061 - mae: 0.0563 - val_loss: 0.0053 - val_mae: 0.0523
# Epoch 79/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0048 - mae: 0.0498 - val_loss: 0.0044 - val_mae: 0.0468
# Epoch 80/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.0041 - mae: 0.0462 - val_loss: 0.0039 - val_mae: 0.0451
# Epoch 81/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.0038 - mae: 0.0442 - val_loss: 0.0039 - val_mae: 0.0442

# %%
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn, lstm_cell_29_layer_call_and_return_conditional_losses, lstm_cell_30_layer_call_fn while saving (showing 5 of 25). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd1263a55d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd1f11625d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd1e0697650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd0c5dfbbd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fd14c710a50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model(model_path)

# %% [markdown]
# ## Analytics
# Here we compute some analytics (just to get a very rough idea: there is no test set, thus these analytics are not so good!)

# %%
X = x[100:200]
Y = y[100:200]
predictions = model.predict(X)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(Y.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(Y.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (100, 864, 7)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.0032691357>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.04092649>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
inspect_multivariate_prediction(X, Y, predictions, dataset.columns, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(Y[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
reg_telescope = 864
X_test_reg, y_test_reg  = chunk(normalized_ds, window, reg_telescope, stride)
X_test_reg = X_test_reg[-10:]
y_test_reg = y_test_reg[-10:]
X_test_reg.shape, y_test_reg.shape
# Out:
# ((10, 300, 7), (10, 864, 7))

# %%
# Autoregressive Forecasting
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.0034567737>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.041238934>)

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, dataset.columns, reg_telescope)
